# %%
from lxml import html
import requests

# %%
import requests as req

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from bs4 import BeautifulSoup

# %%
from urllib.request import urlopen

# %%
resp = req.get("https://www.sts.pl")

# %%
# %matplotlib inline

# %%
print(resp.text)
# Out:
# TS live sprawia, \u017ce nie musisz zbyt du\u017co my\u015ble\u0107, aby by\u0107 na bie\u017c\u0105co z interesuj\u0105cym\\r\\n                    Ci\u0119 wydarzeniem. Rzut oka na STS live i wiesz, co si\u0119 dzieje w meczu, kto ma przewag\u0119 i co mo\u017ce si\u0119\\r\\n                    wydarzy\u0107. Dos\u0142ownie chwila wystarczy na rozeznanie i postawienie kuponu, kt\u00f3ry mo\u017ce okaza\u0107 si\u0119\\r\\n                    zwyci\u0119ski. Nawet, gdy nie b\u0119dziesz \u015bledzi\u0142 przebiegu meczu od pierwszego gwizdka, w ka\u017cdej chwili\\r\\n                    mo\u017cesz podejrze\u0107 statystyki w STS live oraz najwa\u017cniejsze zdarzenia. To jeszcze nie wszystko, bo z\\r\\n                    wielu mecz\u00f3w dost\u0119pne na naszej stronie s\u0105 transmisje STS live. Dzi\u0119ki temu mo\u017cna \u015bledzi\u0107 na\\r\\n                    telefonie czy laptopie dany mecz live i na w\u0142asne oczy widzie\u0107, co si\u0119 dzieje i wyci\u0105ga\u0107 odpowiednie\\r\\n                    wnioski. A nast\u0119pnie obstawi\u0107 wybrany przez Ciebie zak\u0142ad na \u017cywo!\\u003C\\\/p\\u003E\\r\\n            \\u003C\\\/div\\u003E\\r\\n            \\u003Cdiv class=\\u0022box\\u0022\\u003E\\r\\n                \\u003Ch2\\u003EZak\u0142ady live mog\u0105 da\u0107 wi\u0119ksze wygrane\\u003C\\\/h2\\u003E\\r\\n                \\u003Chr\\u003E\\r\\n                \\u003Cp\\u003EWspominali\u015bmy o zwrotach akcji, kt\u00f3re nie tylko dodaj\u0105\\r\\n                    emocji i adrenaliny kibicom oraz graczom.\\r\\n                    Zak\u0142ady live daj\u0105 tak\u017ce mo\u017cliwo\u015b\u0107 wi\u0119kszych wygranych. Kurs na zwyci\u0119stwo dru\u017cyny, kt\u00f3ra\\r\\n                    przegrywa np. 0:2 jest wielokrotnie wy\u017cszy w trakcie meczu, a przecie\u017c w ko\u0144c\u00f3wce spotkania zesp\u00f3\u0142\\r\\n                    mo\u017ce odrobi\u0107 straty i przechyli\u0107 szal\u0119 na w\u0142asn\u0105 stron\u0119. Tak naprawd\u0119 jeden z\u0142oty strza\u0142 w zak\u0142adach\\r\\n                    live mo\u017ce sprawi\u0107, \u017ce zwyk\u0142y kupon da wygran\u0105, o kt\u00f3rej przed meczem gracz m\u00f3g\u0142 tylko pomarzy\u0107.\\r\\n                    W ostatniej edycji Ligi Mistrz\u00f3w zwroty akcji i odrabianie strat by\u0142o na porz\u0105dku dziennym, co\\r\\n                    stanowi\u0142o nie lada okazj\u0119 dla odwa\u017cniejszych graczy w zak\u0142adach live. Poza tym zak\u0142ady na \u017cywo s\u0105\\r\\n                    rozliczane niemal natychmiast po zako\u0144czeniu typowanego zdarzenia. Je\u017celi obstawiasz np. zwyci\u0119zc\u0119\\r\\n                    po\u0142owy, gema lub seta w tenisie, to zak\u0142ad ten zostanie rozliczony w trakcie meczu zaraz po\\r\\n                    zako\u0144czeniu obstawianego zdarzenia, a nie ca\u0142ego meczu. To wszystko sprawia, \u017ce gracze zak\u0142ad\u00f3w\\r\\n                    bukmacherskich ch\u0119tnie korzystaj\u0105 z zak\u0142ad\u00f3w na \u017cywo!\\u003C\\\/p\\u003E\\r\\n            \\u003C\\\/div\\u003E\\r\\n        \\u003C\\\/div\\u003E\\r\\n    \\u003C\\\/div\\u003E\\r\\n    \\u003Cspan class=\\u0022elementSeparatorOnFrontend\\u0022\\u003E\\u003C\\\/span\\u003E\\r\\n\\u003C\\\/div\\u003E\\r\\n\\r\\n\\r\\n\\r\\n\\u003Cdiv style=\\u0022display: none;\\u0022 id=\\u0022vs-banner\\u0022\\u003E\\u003Cdiv class=\\u0022promo-event-mask-live\\u0022\\u003E\\u003C\\\/div\\u003E\\u003Cdiv class=\\u0022vs-banner-info-wrapper\\u0022\\u003E\\u003Cspan class=\\u0022vs-banner-txt-one\\u0022\\u003EWIRTUALNE SPORTY\\u003C\\\/span\\u003E\\u003Cspan class=\\u0022vs-banner-txt-two\\u0022\\u003EEmocje ca\u0142\u0105 dob\u0119!\\u003C\\\/span\\u003E\\u003Ca href=\\u0022http:\\\/\\\/bit.ly\\\/SportyWirtualne\\u0022\\u003E\\u003Cspan\\u003ESPRAWD\u0179!\\u003C\\\/span\\u003E\\u003C\\\/a\\u003E\\u003C\\\/div\\u003E\\u003C\\\/div\\u003E\\r\\n\\r\\n\\u003Cdiv id=\\u0022lift-lv-footer\\u0022 class=\\u0022li ...
#             </script>
# <script>
#             if (typeof customcms !== 'undefined') {
#                 customcms && customcms.init({"polecane":{"12":{"id":12,"title":"Japonia - Polska","link":"https:\/\/www.sts.pl\/pl\/oferta\/zaklady-bukmacherskie\/zaklady-sportowe\/?action=offer&sport=292&region=29987&league=13514&oppty=91106373","icon":"https:\/\/www.sts.pl\/pages\/frontend\/gfx\/icon\/sport\/ms_2018.png","datetime_start":1530158400,"datetime_end":1530194400,"active":1},"13":{"id":13,"title":"Senegal - Kolumbia","link":"https:\/\/www.sts.pl\/pl\/oferta\/zaklady-bukmacherskie\/zaklady-sportowe\/?action=offer&sport=292&region=29987&league=13514&oppty=91106426","icon":"https:\/\/www.sts.pl\/pages\/frontend\/gfx\/icon\/sport\/ms_2018.png","datetime_start":1530158400,"datetime_end":1530194400,"active":1},"14":{"id":14,"title":"Anglia - Belgia","link":"https:\/\/www.sts.pl\/pl\/oferta\/zaklady-bukmacherskie\/zaklady-sportowe\/?action=offer&sport=292&region=29987&league=13514&oppty=91106163","icon":"https:\/\/www.sts.pl\/pages\/frontend\/gfx\/icon\/sport\/ms_2018.png","datetime_start":1530158400,"datetime_end":1530208800,"active":1},"15":{"id":15,"title":"Panama - Tunezja","link":"https:\/\/www.sts.pl\/pl\/oferta\/zaklady-bukmacherskie\/zaklady-sportowe\/?action=offer&sport=292&region=29987&league=13514&oppty=91106216","icon":"https:\/\/www.sts.pl\/pages\/frontend\/gfx\/icon\/sport\/ms_2018.png","datetime_start":1530158400,"datetime_end":1530208800,"active":1},"90":{"id":90,"title":"eliminacje M\u015a","link":"https:\/\/www.sts.pl\/pl\/oferta\/zaklady-bukmacherskie\/zaklady-sportowe\/?action=offer&sport=186&region=6480&league=42925&t=1530087752","icon":"https:\/\/www.sts.pl\/pages\/frontend\/gfx\/icon\/sport\/koszykowka.png","datetime_start":1530086400,"datetime_end":1530211500,"active":1},"101":{"id":101,"title":"Liga Narod\u00f3w kobiet","link":"https:\/\/www.sts.pl\/pl\/oferta\/zaklady-bukmacherskie\/zaklady-sportowe\/?action=offer&sport=183&region=29987&league=68619&t=1529961041","icon":"https:\/\/www.sts.pl\/pages\/frontend\/gfx\/icon\/sport\/siatkowka.png","datetime_start":1529960400,"datetime_end":1530275400,"active":1}},"banery":[{"id":85,"title1":"SPORTY WIRTUALNE","title2":"Emocje ca\u0142\u0105 dob\u0119!","title3":"Graj i wygrywaj o ka\u017cdej porze","url":"https:\/\/www.sts.pl\/pl\/oferta\/sporty-wirtualne\/#\/","btn":"SPRAWD\u0179","default":null,"start":1525638900,"end":1525665600,"data":{"offer":[],"sizes":{"1":"18","2":"30","3":"22"},"button":{"type":"1"}},"active":false,"nologin":0},{"id":78,"title1":"P\u0141ATNO\u015aCI","title2":"Szybka wyp\u0142ata ca\u0142\u0105 dob\u0119!","title3":"Do niedzieli (28.01., 23:59) wyp\u0142acisz \u015brodki  <br> nawet w 15 minut przez 24 godziny na dob\u0119.","url":"https:\/\/www.sts.pl\/pl\/top-menu\/platnosci\/","btn":"WI\u0118CEJ","default":null,"start":1517148000,"end":1517176800,"data":{"offer":[],"sizes":{"1":"18","2":"30","3":"22"},"button":{"type":"1"}},"active":false,"nologin":0}],"prawy":[{"id":43,"title1":"","title2":"","link":"http:\/\/redirect.sts.pl\/?r=pewna-kasa","datetime_start":1530086400,"datetime_end":1530136740,"active":1,"login":1,"nologin":1,"imagetime":1529914079,"target_blank":0},{"id":8,"title1":"Bonus powitalny","title2":"500 PLN na start","link":"https:\/\/www.sts.pl\/\/pl\/bonusy\/#bonus-na-start","datetime_start":false,"datetime_end":false,"active":1,"login":0,"nologin":1,"imagetime":1510932568,"target_blank":0},{"id":42,"title1":"","title2":"","link":"http:\/\/redirect.sts.pl\/?r=pewny-start","datetime_start":1530172800,"datetime_end":1530223140,"active":1,"login":1,"nologin":1,"imagetime":1529825508,"target_blank":0},{"id":16,"title1":"FUNDACJA","title2":"Przeka\u017c 1%","link":"https:\/\/sporttwojaszansa.pl\/fundacja-opp","datetime_start":1521111600,"datetime_end":1524736800,"active":1,"login":1,"nologin":1,"imagetime":1521032856,"target_blank":0},{"id":15,"title1":"MOBILE BONUS","title2":"20 PLN czeka","link":"http:\/\/redirect.sts.pl\/?r=bonus-mobile","datetime_start":1526716800,"datetime_end":1526853300,"active":0,"login":0 ...
#             }
#
#             projectlib.init({"base":{"url-root":"https:\/\/www.sts.pl\/","url-gfx":"https:\/\/www.sts.pl\/pages\/frontend\/gfx\/","url-prematch-home":"https:\/\/www.sts.pl\/pl\/oferta\/zaklady-bukmacherskie\/","url-registration":"https:\/\/www.sts.pl\/pl\/registration\/","url-check-rankings":"https:\/\/www.sts.pl\/pl\/klub-sts\/sprawdz-rankingi","url-ga-aftelogin":"pl\/user\/logowanie\/?caller","actual-lang":"pl","is-guest":true,"expiration-limit":false,"fb-app-id":"243992215772277"},"messages":{"":"","KLIKNIJ I ODBIERZ 50 PLN NA GR\u0118":"KLIKNIJ I ODBIERZ 50 PLN NA GR\u0118","Dzi\u0119ki Twojemu kumplowi mo\u017cesz otrzyma\u0107 50 z\u0142otych na gr\u0119 w STS. Sprawd\u017a, co wystarczy zrobi\u0107.":"Dzi\u0119ki Twojemu kumplowi mo\u017cesz otrzyma\u0107 50 z\u0142otych na gr\u0119 w STS. Sprawd\u017a, co wystarczy zrobi\u0107.","Hej, chcesz wygra\u0107":"Hej, chcesz wygra\u0107","z STS.pl":"z STS.pl","Stawka":"Stawka","Zdarzenia":"Zdarzenia","Grupy":"Grupy","Ewentualna&nbsp;wygrana":"Ewentualna&nbsp;wygrana","Prosimy czeka\u0107, autoryzacja potrwa maksymalnie":"Prosimy czeka\u0107, autoryzacja potrwa maksymalnie","Coupon is being authorized":"Trwa autoryzacja kuponu","Mniej":"Mniej","Wi\u0119cej":"Wi\u0119cej"}});
#         </script>
# </div>
# <script type="text/javascript" src="https://www.sts.pl/userdata/files/clientjs-body.js?1565243312"></script>
# <script type="text/javascript" src="https://content.sts.pl/clientstyles/sts_pl/prod/clientbody.js"></script>
# </body>
# </html>

# %%
soup.text
# Out:
# n\n\n\n\n\n2770\n\n\n\n\n\n\n\n\n13.09 / 17:30\n\n\n\n\n\nBędzin\n5.50\n\n\n\n\nWarszawa\n1.15\n\n\n\n\n\n30\n\n\n\n\n\n2690\n\n\n\n\n\n\n\n\n13.09 / 20:30\n\n\n\n\n\nZawiercie\n2.50\n\n\n\n\nJastrzębie\n1.52\n\n\n\n\n\n30\n\n\n\n\n\n2772\n\n\n\n\n\n\n\n\n\nHokej na Lodzie - PHL, Polska\n\n\n\n\n\n11.09 / 18:00\n\n\n\n\n\nSanok\n 5.39\n\n\n\n\nX\n5.00\n\n\n\n\nTychy\n1.45\n\n\n\n\n\n12\n\n\n\n\n\n61763\n\n\n\n\n\n\n\n\n11.09 / 18:00\n\n\n\n\n\nNowy Targ\n1.85\n\n\n\n\nX\n4.50\n\n\n\n\nCracovia\n3.20\n\n\n\n\n\n12\n\n\n\n\n\n61832\n\n\n\n\n\n\n\n\n11.09 / 18:00\n\n\n\n\n\nJastrzębie\n1.18\n\n\n\n\nX\n7.50\n\n\n\n\nSosnowiec\n10.58\n\n\n\n\n\n9\n\n\n\n\n\n61852\n\n\n\n\n\n\n\n\n11.09 / 18:30\n\n\n\n\n\nToruń\n3.78\n\n\n\n\nX\n4.50\n\n\n\n\nKatowice\n1.70\n\n\n\n\n\n10\n\n\n\n\n\n61791\n\n\n\n\n\n\n\n\n\nPiłka Nożna - 2 liga, Polska\n\n\n\n\n\n11.09 / 17:00\n\n\n\n\n\nSuwałki\n2.15\n\n\n\n\nX\n3.40\n\n\n\n\nSkra Częstochowa\n3.16\n\n\n\n\n\n58\n\n\n\n\n\n1403\n\n\n\n\n\n\n\n\n12.09 / 15:00\n\n\n\n\n\nStal Rzeszów\n1.85\n\n\n\n\nX\n3.50\n\n\n\n\nGrudziądz\n4.02\n\n\n\n\n\n58\n\n\n\n\n\n1422\n\n\n\n\n\n\n\n\n12.09 / 17:00\n\n\n\n\n\nChojnice\n1.85\n\n\n\n\nX\n3.50\n\n\n\n\nPruszków\n4.02\n\n\n\n\n\n58\n\n\n\n\n\n1404\n\n\n\n\n\n\n\n\n12.09 / 18:00\n\n\n\n\n\nM. Lublin\n2.05\n\n\n\n\nX\n3.40\n\n\n\n\nStargard\n3.41\n\n\n\n\n\n58\n\n\n\n\n\n1416\n\n\n\n\n\n\n\n\n12.09 / 18:00\n\n\n\n\n\nKalisz\n2.05\n\n\n\n\nX\n3.40\n\n\n\n\nGarbarnia\n 3.40\n\n\n\n\n\n58\n\n\n\n\n\n1423\n\n\n\n\n\n\n\n\n12.09 / 18:00\n\n\n\n\n\nBytów\n1.85\n\n\n\n\nX\n3.50\n\n\n\n\nElbląg\n4.02\n\n\n\n\n\n58\n\n\n\n\n\n1428\n\n\n\n\n\n\n\n\n12.09 / 18:00\n\n\n\n\n\nOstróda\n2.15\n\n\n\n\nX\n3.40\n\n\n\n\nSiedlce\n3.16\n\n\n\n\n\n58\n\n\n\n\n\n1437\n\n\n\n\n\n\n\n\n13.09 / 19:00\n\n\n\n\n\nGKS Katowice\n1.85\n\n\n\n\nX\n3.65\n\n\n\n\nLech II\n3.84\n\n\n\n\n\n58\n\n\n\n\n\n1427\n\n\n\n\n\n\n\n\n\nPiłka Ręczna - Superliga, Polska\n\n\n\n\n\n11.09 / 18:00\n\n\n\n\n\nGłogów\n1.95\n\n\n\n\nX\n8.00\n\n\n\n\nOpole\n2.29\n\n\n\n\n\n20\n\n\n\n\n\n1053\n\n\n\n\n\n\n\n\n11.09 / 19:00\n\n\n\n\n\nKielce\n1.03\n\n\n\n\nX\n27.00\n\n\n\n\nSzczecin\n14.85\n\n\n\n\n\n8\n\n\n\n\n\n1076\n \n\n\n\n\n\n\n\n12.09 / 15:00\n\n\n\n\n\nGdańsk\n2.05\n\n\n\n\nX\n7.25\n\n\n\n\nKalisz\n2.22\n\n\n\n\n\n0\n\n\n\n\n\n1059\n\n\n\n\n\n\n\n\n12.09 / 17:30\n\n\n\n\n\nPłock\n1.18\n\n\n\n\nX\n12.25\n\n\n\n\nZabrze\n6.84\n\n\n\n\n\n0\n\n\n\n\n\n1057\n\n\n\n\n\n\n\n\n12.09 / 20:15\n\n\n\n\n\nPuławy\n1.07\n\n\n\n\nX\n17.50\n\n\n\n\nKwidzyn\n11.97\n\n\n\n\n\n0\n\n\n\n\n\n1073\n\n\n\n\n\n\n\n\n13.09 / 15:00\n\n\n\n\n\nMielec\n1.60\n\n\n\n\nX\n8.00\n\n\n\n\nTarnów\n3.07\n\n\n\n\n\n0\n\n\n\n\n\n1037\n\n\n\n\n\n\n\n\n13.09 / 17:30\n\n\n\n\n\nPiotrków Tryb.\n2.24\n\n\n\n\nX\n7.75\n\n\n\n\nLubin\n2.00\n\n\n\n\n\n0\n\n\n\n\n\n1029\n\n\n\n\n\n\n\n\n\nPiłka Nożna - 1 liga, Polska\n\n\n\n\n\n11.09 / 16:00\n\n\n\n\n\nJastrzębie\n3.09\n\n\n\n\nX\n3.20\n\n\n\n\nRadomiak\n2.40\n\n\n\n\n\n61\n\n\n\n\n\n1397\n\n\n\n\n\n\n\n\n11.09 / 19:00\n\n\n\n\n\n Legnica\n1.75\n\n\n\n\nX\n3.80\n\n\n\n\nResovia\n4.59\n\n\n\n\n\n60\n\n\n\n\n\n1309\n\n\n\n\n\n\n\n\n11.09 / 19:00\n\n\n\n\n\nNiepołomice\n2.45\n\n\n\n\nX\n3.35\n\n\n\n\nKorona\n2.89\n\n\n\n\n\n61\n\n\n\n\n\n1340\n\n\n\n\n\n\n\n\n11.09 / 19:45\n\n\n\n\n\nOpole\n2.45\n\n\n\n\nX\n3.35\n\n\n\n\nSosnowiec\n2.89\n\n\n\n\n\n61\n\n\n\n\n\n1314\n\n\n\n\n\n\n\n\n12.09 / 12:40\n\n\n\n\n\nŁKS Łódź\n1.42\n\n\n\n\nX\n4.60\n\n\n\n\nOlsztyn\n7.63\n\n\n\n\n\n60\n\n\n\n\n\n1364\n\n\n\n\n\n\n\n\n12.09 / 19:00\n\n\n\n\n\nTychy\n2.00\n\n\n\n\nX\n3.50\n\n\n\n\nSandecja\n3.75\n\n\n\n\n\n61\n\n\n\n\n\n1391\n\n\n\n\n\n\n\n\n12.09 / 20:00\n\n\n\n\n\nNieciecza\n1.57\n\n\n\n\nX\n4.15\n\n\n\n\nBełchatów\n5.72\n\n\n\n\n\n60\n\n\n\n\n\n1346\n\n\n\n\n\n\n\n\n13.09 / 12:40\n\n\n\n\n\nŁęczna\n3.20\n\n\n\n\nX\n3.50\n\n\n\n\nArka\n2.20\n\n\n\n\n\n61\n\n\n\n\n\n1381\n\n\n\n\n\n\n\n\n\nPiłka Nożna - Ekstraklasa, Polska\n\n\n\n\n\n11.09 / 18:00\n\n\n\n\n\nJagiellonia\n1.85\n\n\n\n\nX\n3.60\n\n\n\n\nPodbeskidzie\n4.27 ...

# %%
soup.find_all('tr')
# Out:
#  <a class="disabled"></a>
#  </td>
#  <td class="bet_id">
#  <a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/superoferta/piatek/bordeaux/201/6582/4489/298439274/">
#  30
#  </a>
#  </td>
#  </tr>,
#  <tr>
#  <td class="bet tip1847 bigTip" data-odds-id="831200307" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"30","id_odds":"831200307","odds_value":"4.09","id_opportunity":"298439274","match_name":"Bordeaux - Lyon","tip_name_formated":"Bordeaux","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Bordeaux
#  <span>4.09</span>
#  </a>
#  </td>
#  <td class="bet tip1846 smallTip" data-odds-id="831200312" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"30","id_odds":"831200312","odds_value":"3.35","id_opportunity":"298439274","match_name":"Bordeaux - Lyon","tip_name_formated":"X","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  X
#  <span>3.35</span>
#  </a>
#  </td>
#  <td class="bet tip1848 bigTip" data-odds-id="831200309" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"30","id_odds":"831200309","odds_value":"2.05","id_opportunity":"298439274","match_name":"Bordeaux - Lyon","tip_name_formated":"Lyon","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Lyon
#  <span>2.05</span>
#  </a>
#  </td>
#  </tr>,
#  <tr>
#  <td class="date_time"><a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/superoferta/piatek/dundalk/201/6582/4489/298442243/">11.09 / 21:00</a></td>
#  <td>
#  <table class="subTable">
#  <tr>
#  <td class="bet tip1847 bigTip" data-odds-id="831207169" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"40","id_odds":"831207169","odds_value":"1.45","id_opportunity":"298442243","match_name":"Dundalk - Shelbourne","tip_name_formated":"Dundalk","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Dundalk
#  <span>1.45</span>
#  </a>
#  </td>
#  <td class="bet tip1846 smallTip" data-odds-id="831207174" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"40","id_odds":"831207174","odds_value":"4.50","id_opportunity":"298442243","match_name":"Dundalk - Shelbourne","tip_name_formated":"X","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  X
#  <span>4.50</span>
#  </a>
#  </td>
#  <td class="bet tip1848 bigTip" data-odds-id="831207171" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"40","id_odds":"831207171","odds_value":"7.70","id_opportunity":"298442243","match_name":"Dundalk - Shelbourne","tip_name_formated":"Shelbourne","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Shelbourne
#  <span>7.70</span>
#  </a>
#  </td>
#  </tr>
#  </table>
#  </td>
#  <td class="support_bets"><a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/superoferta/piatek/dundalk/201/6582/4489/298442243/">0</a></td>
#  <td class="stats">
#  <a class="disabled"></a>
#  </td>
#  <td class="bet_id">
#  <a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/superoferta/piatek/dundalk/201/6582/4489/298442243/">
#  40
#  </a>
#  </td>
#  </tr>,
#  <tr>
#  <td class="bet tip1847 bigTip" data-odds-id="831207169" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"40","id_odds":"831207169","odds_value":"1.45","id_opportunity":"298442243","match_name":"Dundalk - Shelbourne","tip_name_formated":"Dundalk","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Dundalk
#  <span>1.45</span>
#  </a>
#  </td>
#  <td class="bet tip1846 smallTip" data-odds-id="831207174" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"40","id_odds":"831207174","odds_value":"4.50","id_opportunity":"298442243","match_name":"Dundalk - Shelbourne","tip_name_formated":"X","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  X
#  <span>4.50</span>
#  </a>
#  </td>
#  <td class="bet tip1848 bigTip" data-odds-id="831207171" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"40","id_odds":"831207171","odds_value":"7.70","id_opportunity":"298442243","match_name":"Dundalk - Shelbourne","tip_name_formated":"Shelbourne","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Shelbourne
#  <span>7.70</span>
#  </a>
#  </td>
#  </tr>,
#  <tr>
#  <td class="date_time"><a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/superoferta/piatek/carreno-busta-p/201/6582/4489/298442300/">11.09 / 22:00</a></td>
#  <td>
#  <table class="subTable">
#  <tr>
#  <td class="bet tip1847 bigTip" data-odds-id="831207352" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"41","id_odds":"831207352","odds_value":"3.06","id_opportunity":"298442300","match_name":"Carreno Busta P. - Zverev A.","tip_name_formated":"Carreno Busta P.","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Carreno Busta P.
#  <span>3.06</span>
#  </a>
#  </td>
#  <td class="bet tip1846 smallTip blank" data-odds-id="831207357" false="" return="">
#  <a href="#" rel="nofollow">
#  X
#  <span>-</span>
#  </a>
#  </td>
#  <td class="bet tip1848 bigTip" data-odds-id="831207354" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"41","id_odds":"831207354","odds_value":"1.42","id_opportunity":"298442300","match_name":"Carreno Busta P. - Zverev A.","tip_name_formated":"Zverev A.","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Zverev A.
#  <span>1.42</span>
#  </a>
#  </td>
#  </tr>
#  </table>
#  </td>
#  <td class="support_bets"><a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/superoferta/piatek/carreno-busta-p/201/6582/4489/298442300/">0</a></td>
#  <td class="stats">
#  <a class="disabled"></a>
#  </td>
#  <td class="bet_id">
#  <a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/superoferta/piatek/carreno-busta-p/201/6582/4489/298442300/">
#  41
#  </a>
#  </td>
#  </tr>,
#  <tr>
#  <td class="bet tip1847 bigTip" data-odds-id="831207352" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"41","id_odds":"831207352","odds_value":"3.06","id_opportunity":"298442300","match_name":"Carreno Busta P. - Zverev A.","tip_name_formated":"Carreno Busta P.","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Carreno Busta P.
#  <span>3.06</span>
#  </a>
#  </td>
#  <td class="bet tip1846 smallTip blank" data-odds-id="831207357" false="" return="">
#  <a href="#" rel="nofollow">
#  X
#  <span>-</span>
#  </a>
#  </td>
#  <td class="bet tip1848 bigTip" data-odds-id="831207354" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"41","id_odds":"831207354","odds_value":"1.42","id_opportunity":"298442300","match_name":"Carreno Busta P. - Zverev A.","tip_name_formated":"Zverev A.","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Zverev A.
#  <span>1.42</span>
#  </a>
#  </td>
#  </tr>,
#  <tr>
#  <td class="date_time"><a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/superoferta/piatek/la-clippers/201/6582/4489/298442775/">12.09 / 00:30</a></td>
#  <td>
#  <table class="subTable">
#  <tr>
#  <td class="bet tip1847 bigTip" data-odds-id="831208346" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"42","id_odds":"831208346","odds_value":"1.30","id_opportunity":"298442775","match_name":"LA Clippers - Denver","tip_name_formated":"LA Clippers","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  LA Clippers
#  <span>1.30</span>
#  </a>
#  </td>
#  <td class="bet tip1846 smallTip blank" data-odds-id="831208351" false="" return="">
#  <a href="#" rel="nofollow">
#  X
#  <span>-</span>
#  </a>
#  </td>
#  <td class="bet tip1848 bigTip" data-odds-id="831208348" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"42","id_odds":"831208348","odds_value":"3.82","id_opportunity":"298442775","match_name":"LA Clippers - Denver","tip_name_formated":"Denver","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Denver
#  <span>3.82</span>
#  </a>
#  </td>
#  </tr>
#  </table>
#  </td>
#  <td class="support_bets"><a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/superoferta/piatek/la-clippers/201/6582/4489/298442775/">0</a></td>
#  <td class="stats">
#  <a class="disabled"></a>
#  </td>
#  <td class="bet_id">
#  <a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/superoferta/piatek/la-clippers/201/6582/4489/298442775/">
#  42
#  </a>
#  </td>
#  </tr>,
#  <tr>
#  <td class="bet tip1847 bigTip" data-odds-id="831208346" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"42","id_odds":"831208346","odds_value":"1.30","id_opportunity":"298442775","match_name":"LA Clippers - Denver","tip_name_formated":"LA Clippers","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  LA Clippers
#  <span>1.30</span>
#  </a>
#  </td>
#  <td class="bet tip1846 smallTip blank" data-odds-id="831208351" false="" return="">
#  <a href="#" rel="nofollow">
#  X
#  <span>-</span>
#  </a>
#  </td>
#  <td class="bet tip1848 bigTip" data-odds-id="831208348" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"42","id_odds":"831208348","odds_value":"3.82","id_opportunity":"298442775","match_name":"LA Clippers - Denver","tip_name_formated":"Denver","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Denver
#  <span>3.82</span>
#  </a>
#  </td>
#  </tr>,
#  <tr>
#  <th colspan="5" style="text-align:left">
#  Zakłady Specjalne - CZWARTEK, HIT DNIA
#  </th>
#  </tr>,
#  <tr>
#  <td class="date_time"><a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/hit-dnia/czwartek/bahia/201/6613/4792/298254335/">11.09 / 00:15</a></td>
#  <td>
#  <table class="subTable">
#  <tr>
#  <td class="bet tip1847 bigTip" data-odds-id="830520963" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"7","id_odds":"830520963","odds_value":"3.25","id_opportunity":"298254335","match_name":"Bahia - Gremio","tip_name_formated":"Bahia","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Bahia
#  <span>3.25</span>
#  </a>
#  </td>
#  <td class="bet tip1846 smallTip" data-odds-id="830520968" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"7","id_odds":"830520968","odds_value":"3.20","id_opportunity":"298254335","match_name":"Bahia - Gremio","tip_name_formated":"X","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  X
#  <span>3.20</span>
#  </a>
#  </td>
#  <td class="bet tip1848 bigTip" data-odds-id="830520965" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"7","id_odds":"830520965","odds_value":"2.55","id_opportunity":"298254335","match_name":"Bahia - Gremio","tip_name_formated":"Gremio","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Gremio
#  <span>2.55</span>
#  </a>
#  </td>
#  </tr>
#  </table>
#  </td>
#  <td class="support_bets"><a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/hit-dnia/czwartek/bahia/201/6613/4792/298254335/">0</a></td>
#  <td class="stats">
#  <a class="disabled"></a>
#  </td>
#  <td class="bet_id">
#  <a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/hit-dnia/czwartek/bahia/201/6613/4792/298254335/">
#  7
#  </a>
#  </td>
#  </tr>,
#  <tr>
#  <td class="bet tip1847 bigTip" data-odds-id="830520963" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"7","id_odds":"830520963","odds_value":"3.25","id_opportunity":"298254335","match_name":"Bahia - Gremio","tip_name_formated":"Bahia","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Bahia
#  <span>3.25</span>
#  </a>
#  </td>
#  <td class="bet tip1846 smallTip" data-odds-id="830520968" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"7","id_odds":"830520968","odds_value":"3.20","id_opportunity":"298254335","match_name":"Bahia - Gremio","tip_name_formated":"X","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  X
#  <span>3.20</span>
#  </a>
#  </td>
#  <td class="bet tip1848 bigTip" data-odds-id="830520965" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"7","id_odds":"830520965","odds_value":"2.55","id_opportunity":"298254335","match_name":"Bahia - Gremio","tip_name_formated":"Gremio","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Gremio
#  <span>2.55</span>
#  </a>
#  </td>
#  </tr>,
#  <tr>
#  <td class="date_time"><a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/hit-dnia/czwartek/williams-s/201/6613/4792/298432862/">11.09 / 02:15</a></td>
#  <td>
#  <table class="subTable">
#  <tr>
#  <td class="bet tip1847 bigTip" data-odds-id="831174069" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"2","id_odds":"831174069","odds_value":"2.10","id_opportunity":"298432862","match_name":"Williams S. - Azarenka V.","tip_name_formated":"Williams S.","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Williams S.
#  <span>2.10</span>
#  </a>
#  </td>
#  <td class="bet tip1846 smallTip blank" data-odds-id="831174074" false="" return="">
#  <a href="#" rel="nofollow">
#  X
#  <span>-</span>
#  </a>
#  </td>
#  <td class="bet tip1848 bigTip" data-odds-id="831174071" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"2","id_odds":"831174071","odds_value":"1.90","id_opportunity":"298432862","match_name":"Williams S. - Azarenka V.","tip_name_formated":"Azarenka V.","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Azarenka V.
#  <span>1.90</span>
#  </a>
#  </td>
#  </tr>
#  </table>
#  </td>
#  <td class="support_bets"><a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/hit-dnia/czwartek/williams-s/201/6613/4792/298432862/">0</a></td>
#  <td class="stats">
#  <a class="disabled"></a>
#  </td>
#  <td class="bet_id">
#  <a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/hit-dnia/czwartek/williams-s/201/6613/4792/298432862/">
#  2
#  </a>
#  </td>
#  </tr>,
#  <tr>
#  <td class="bet tip1847 bigTip" data-odds-id="831174069" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"2","id_odds":"831174069","odds_value":"2.10","id_opportunity":"298432862","match_name":"Williams S. - Azarenka V.","tip_name_formated":"Williams S.","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Williams S.
#  <span>2.10</span>
#  </a>
#  </td>
#  <td class="bet tip1846 smallTip blank" data-odds-id="831174074" false="" return="">
#  <a href="#" rel="nofollow">
#  X
#  <span>-</span>
#  </a>
#  </td>
#  <td class="bet tip1848 bigTip" data-odds-id="831174071" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"2","id_odds":"831174071","odds_value":"1.90","id_opportunity":"298432862","match_name":"Williams S. - Azarenka V.","tip_name_formated":"Azarenka V.","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Azarenka V.
#  <span>1.90</span>
#  </a>
#  </td>
#  </tr>,
#  <tr>
#  <th colspan="5" style="text-align:left">
#  Zakłady Specjalne - PIĄTEK, HIT DNIA
#  </th>
#  </tr>,
#  <tr>
#  <td class="date_time"><a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/hit-dnia/piatek/opole/201/6613/4793/298434126/">11.09 / 19:45</a></td>
#  <td>
#  <table class="subTable">
#  <tr>
#  <td class="bet tip1847 bigTip" data-odds-id="831178527" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"3","id_odds":"831178527","odds_value":"2.65","id_opportunity":"298434126","match_name":"Opole - Sosnowiec","tip_name_formated":"Opole","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Opole
#  <span>2.65</span>
#  </a>
#  </td>
#  <td class="bet tip1846 smallTip" data-odds-id="831178532" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"3","id_odds":"831178532","odds_value":"3.45","id_opportunity":"298434126","match_name":"Opole - Sosnowiec","tip_name_formated":"X","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  X
#  <span>3.45</span>
#  </a>
#  </td>
#  <td class="bet tip1848 bigTip" data-odds-id="831178529" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"3","id_odds":"831178529","odds_value":"2.92","id_opportunity":"298434126","match_name":"Opole - Sosnowiec","tip_name_formated":"Sosnowiec","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Sosnowiec
#  <span>2.92</span>
#  </a>
#  </td>
#  </tr>
#  </table>
#  </td>
#  <td class="support_bets"><a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/hit-dnia/piatek/opole/201/6613/4793/298434126/">0</a></td>
#  <td class="stats">
#  <a class="disabled"></a>
#  </td>
#  <td class="bet_id">
#  <a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/hit-dnia/piatek/opole/201/6613/4793/298434126/">
#  3
#  </a>
#  </td>
#  </tr>,
#  <tr>
#  <td class="bet tip1847 bigTip" data-odds-id="831178527" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"3","id_odds":"831178527","odds_value":"2.65","id_opportunity":"298434126","match_name":"Opole - Sosnowiec","tip_name_formated":"Opole","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Opole
#  <span>2.65</span>
#  </a>
#  </td>
#  <td class="bet tip1846 smallTip" data-odds-id="831178532" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"3","id_odds":"831178532","odds_value":"3.45","id_opportunity":"298434126","match_name":"Opole - Sosnowiec","tip_name_formated":"X","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  X
#  <span>3.45</span>
#  </a>
#  </td>
#  <td class="bet tip1848 bigTip" data-odds-id="831178529" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"3","id_odds":"831178529","odds_value":"2.92","id_opportunity":"298434126","match_name":"Opole - Sosnowiec","tip_name_formated":"Sosnowiec","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Sosnowiec
#  <span>2.92</span>
#  </a>
#  </td>
#  </tr>,
#  <tr>
#  <td class="date_time"><a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/hit-dnia/piatek/medvedev-d/201/6613/4793/298434152/">11.09 / 22:00</a></td>
#  <td>
#  <table class="subTable">
#  <tr>
#  <td class="bet tip1847 bigTip" data-odds-id="831178641" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"4","id_odds":"831178641","odds_value":"1.90","id_opportunity":"298434152","match_name":"Medvedev D. - Thiem D.","tip_name_formated":"Medvedev D.","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Medvedev D.
#  <span>1.90</span>
#  </a>
#  </td>
#  <td class="bet tip1846 smallTip blank" data-odds-id="831178646" false="" return="">
#  <a href="#" rel="nofollow">
#  X
#  <span>-</span>
#  </a>
#  </td>
#  <td class="bet tip1848 bigTip" data-odds-id="831178643" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"4","id_odds":"831178643","odds_value":"2.10","id_opportunity":"298434152","match_name":"Medvedev D. - Thiem D.","tip_name_formated":"Thiem D.","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Thiem D.
#  <span>2.10</span>
#  </a>
#  </td>
#  </tr>
#  </table>
#  </td>
#  <td class="support_bets"><a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/hit-dnia/piatek/medvedev-d/201/6613/4793/298434152/">0</a></td>
#  <td class="stats">
#  <a class="disabled"></a>
#  </td>
#  <td class="bet_id">
#  <a href="/pl/zaklady-bukmacherskie/zaklady-specjalne/hit-dnia/piatek/medvedev-d/201/6613/4793/298434152/">
#  4
#  </a>
#  </td>
#  </tr>,
#  <tr>
#  <td class="bet tip1847 bigTip" data-odds-id="831178641" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"4","id_odds":"831178641","odds_value":"1.90","id_opportunity":"298434152","match_name":"Medvedev D. - Thiem D.","tip_name_formated":"Medvedev D.","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Medvedev D.
#  <span>1.90</span>
#  </a>
#  </td>
#  <td class="bet tip1846 smallTip blank" data-odds-id="831178646" false="" return="">
#  <a href="#" rel="nofollow">
#  X
#  <span>-</span>
#  </a>
#  </td>
#  <td class="bet tip1848 bigTip" data-odds-id="831178643" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"4","id_odds":"831178643","odds_value":"2.10","id_opportunity":"298434152","match_name":"Medvedev D. - Thiem D.","tip_name_formated":"Thiem D.","oppty_type_name":"mecz"});return false;'>
#  <a href="#" rel="nofollow">
#  Thiem D.
#  <span>2.10</span>
#  </a>
#  </td>
#  </tr>]

# %%
# removes xml tags
soup = BeautifulSoup(resp.text, 'lxml')

# %%
print(soup)
# Out:
# TS live sprawia, \u017ce nie musisz zbyt du\u017co my\u015ble\u0107, aby by\u0107 na bie\u017c\u0105co z interesuj\u0105cym\\r\\n                    Ci\u0119 wydarzeniem. Rzut oka na STS live i wiesz, co si\u0119 dzieje w meczu, kto ma przewag\u0119 i co mo\u017ce si\u0119\\r\\n                    wydarzy\u0107. Dos\u0142ownie chwila wystarczy na rozeznanie i postawienie kuponu, kt\u00f3ry mo\u017ce okaza\u0107 si\u0119\\r\\n                    zwyci\u0119ski. Nawet, gdy nie b\u0119dziesz \u015bledzi\u0142 przebiegu meczu od pierwszego gwizdka, w ka\u017cdej chwili\\r\\n                    mo\u017cesz podejrze\u0107 statystyki w STS live oraz najwa\u017cniejsze zdarzenia. To jeszcze nie wszystko, bo z\\r\\n                    wielu mecz\u00f3w dost\u0119pne na naszej stronie s\u0105 transmisje STS live. Dzi\u0119ki temu mo\u017cna \u015bledzi\u0107 na\\r\\n                    telefonie czy laptopie dany mecz live i na w\u0142asne oczy widzie\u0107, co si\u0119 dzieje i wyci\u0105ga\u0107 odpowiednie\\r\\n                    wnioski. A nast\u0119pnie obstawi\u0107 wybrany przez Ciebie zak\u0142ad na \u017cywo!\\u003C\\\/p\\u003E\\r\\n            \\u003C\\\/div\\u003E\\r\\n            \\u003Cdiv class=\\u0022box\\u0022\\u003E\\r\\n                \\u003Ch2\\u003EZak\u0142ady live mog\u0105 da\u0107 wi\u0119ksze wygrane\\u003C\\\/h2\\u003E\\r\\n                \\u003Chr\\u003E\\r\\n                \\u003Cp\\u003EWspominali\u015bmy o zwrotach akcji, kt\u00f3re nie tylko dodaj\u0105\\r\\n                    emocji i adrenaliny kibicom oraz graczom.\\r\\n                    Zak\u0142ady live daj\u0105 tak\u017ce mo\u017cliwo\u015b\u0107 wi\u0119kszych wygranych. Kurs na zwyci\u0119stwo dru\u017cyny, kt\u00f3ra\\r\\n                    przegrywa np. 0:2 jest wielokrotnie wy\u017cszy w trakcie meczu, a przecie\u017c w ko\u0144c\u00f3wce spotkania zesp\u00f3\u0142\\r\\n                    mo\u017ce odrobi\u0107 straty i przechyli\u0107 szal\u0119 na w\u0142asn\u0105 stron\u0119. Tak naprawd\u0119 jeden z\u0142oty strza\u0142 w zak\u0142adach\\r\\n                    live mo\u017ce sprawi\u0107, \u017ce zwyk\u0142y kupon da wygran\u0105, o kt\u00f3rej przed meczem gracz m\u00f3g\u0142 tylko pomarzy\u0107.\\r\\n                    W ostatniej edycji Ligi Mistrz\u00f3w zwroty akcji i odrabianie strat by\u0142o na porz\u0105dku dziennym, co\\r\\n                    stanowi\u0142o nie lada okazj\u0119 dla odwa\u017cniejszych graczy w zak\u0142adach live. Poza tym zak\u0142ady na \u017cywo s\u0105\\r\\n                    rozliczane niemal natychmiast po zako\u0144czeniu typowanego zdarzenia. Je\u017celi obstawiasz np. zwyci\u0119zc\u0119\\r\\n                    po\u0142owy, gema lub seta w tenisie, to zak\u0142ad ten zostanie rozliczony w trakcie meczu zaraz po\\r\\n                    zako\u0144czeniu obstawianego zdarzenia, a nie ca\u0142ego meczu. To wszystko sprawia, \u017ce gracze zak\u0142ad\u00f3w\\r\\n                    bukmacherskich ch\u0119tnie korzystaj\u0105 z zak\u0142ad\u00f3w na \u017cywo!\\u003C\\\/p\\u003E\\r\\n            \\u003C\\\/div\\u003E\\r\\n        \\u003C\\\/div\\u003E\\r\\n    \\u003C\\\/div\\u003E\\r\\n    \\u003Cspan class=\\u0022elementSeparatorOnFrontend\\u0022\\u003E\\u003C\\\/span\\u003E\\r\\n\\u003C\\\/div\\u003E\\r\\n\\r\\n\\r\\n\\r\\n\\u003Cdiv style=\\u0022display: none;\\u0022 id=\\u0022vs-banner\\u0022\\u003E\\u003Cdiv class=\\u0022promo-event-mask-live\\u0022\\u003E\\u003C\\\/div\\u003E\\u003Cdiv class=\\u0022vs-banner-info-wrapper\\u0022\\u003E\\u003Cspan class=\\u0022vs-banner-txt-one\\u0022\\u003EWIRTUALNE SPORTY\\u003C\\\/span\\u003E\\u003Cspan class=\\u0022vs-banner-txt-two\\u0022\\u003EEmocje ca\u0142\u0105 dob\u0119!\\u003C\\\/span\\u003E\\u003Ca href=\\u0022http:\\\/\\\/bit.ly\\\/SportyWirtualne\\u0022\\u003E\\u003Cspan\\u003ESPRAWD\u0179!\\u003C\\\/span\\u003E\\u003C\\\/a\\u003E\\u003C\\\/div\\u003E\\u003C\\\/div\\u003E\\r\\n\\r\\n\\u003Cdiv id=\\u0022lift-lv-footer\\u0022 class=\\u0022li ...
#             </script>
# <script>
#             if (typeof customcms !== 'undefined') {
#                 customcms && customcms.init({"polecane":{"12":{"id":12,"title":"Japonia - Polska","link":"https:\/\/www.sts.pl\/pl\/oferta\/zaklady-bukmacherskie\/zaklady-sportowe\/?action=offer&sport=292&region=29987&league=13514&oppty=91106373","icon":"https:\/\/www.sts.pl\/pages\/frontend\/gfx\/icon\/sport\/ms_2018.png","datetime_start":1530158400,"datetime_end":1530194400,"active":1},"13":{"id":13,"title":"Senegal - Kolumbia","link":"https:\/\/www.sts.pl\/pl\/oferta\/zaklady-bukmacherskie\/zaklady-sportowe\/?action=offer&sport=292&region=29987&league=13514&oppty=91106426","icon":"https:\/\/www.sts.pl\/pages\/frontend\/gfx\/icon\/sport\/ms_2018.png","datetime_start":1530158400,"datetime_end":1530194400,"active":1},"14":{"id":14,"title":"Anglia - Belgia","link":"https:\/\/www.sts.pl\/pl\/oferta\/zaklady-bukmacherskie\/zaklady-sportowe\/?action=offer&sport=292&region=29987&league=13514&oppty=91106163","icon":"https:\/\/www.sts.pl\/pages\/frontend\/gfx\/icon\/sport\/ms_2018.png","datetime_start":1530158400,"datetime_end":1530208800,"active":1},"15":{"id":15,"title":"Panama - Tunezja","link":"https:\/\/www.sts.pl\/pl\/oferta\/zaklady-bukmacherskie\/zaklady-sportowe\/?action=offer&sport=292&region=29987&league=13514&oppty=91106216","icon":"https:\/\/www.sts.pl\/pages\/frontend\/gfx\/icon\/sport\/ms_2018.png","datetime_start":1530158400,"datetime_end":1530208800,"active":1},"90":{"id":90,"title":"eliminacje M\u015a","link":"https:\/\/www.sts.pl\/pl\/oferta\/zaklady-bukmacherskie\/zaklady-sportowe\/?action=offer&sport=186&region=6480&league=42925&t=1530087752","icon":"https:\/\/www.sts.pl\/pages\/frontend\/gfx\/icon\/sport\/koszykowka.png","datetime_start":1530086400,"datetime_end":1530211500,"active":1},"101":{"id":101,"title":"Liga Narod\u00f3w kobiet","link":"https:\/\/www.sts.pl\/pl\/oferta\/zaklady-bukmacherskie\/zaklady-sportowe\/?action=offer&sport=183&region=29987&league=68619&t=1529961041","icon":"https:\/\/www.sts.pl\/pages\/frontend\/gfx\/icon\/sport\/siatkowka.png","datetime_start":1529960400,"datetime_end":1530275400,"active":1}},"banery":[{"id":85,"title1":"SPORTY WIRTUALNE","title2":"Emocje ca\u0142\u0105 dob\u0119!","title3":"Graj i wygrywaj o ka\u017cdej porze","url":"https:\/\/www.sts.pl\/pl\/oferta\/sporty-wirtualne\/#\/","btn":"SPRAWD\u0179","default":null,"start":1525638900,"end":1525665600,"data":{"offer":[],"sizes":{"1":"18","2":"30","3":"22"},"button":{"type":"1"}},"active":false,"nologin":0},{"id":78,"title1":"P\u0141ATNO\u015aCI","title2":"Szybka wyp\u0142ata ca\u0142\u0105 dob\u0119!","title3":"Do niedzieli (28.01., 23:59) wyp\u0142acisz \u015brodki  <br> nawet w 15 minut przez 24 godziny na dob\u0119.","url":"https:\/\/www.sts.pl\/pl\/top-menu\/platnosci\/","btn":"WI\u0118CEJ","default":null,"start":1517148000,"end":1517176800,"data":{"offer":[],"sizes":{"1":"18","2":"30","3":"22"},"button":{"type":"1"}},"active":false,"nologin":0}],"prawy":[{"id":43,"title1":"","title2":"","link":"http:\/\/redirect.sts.pl\/?r=pewna-kasa","datetime_start":1530086400,"datetime_end":1530136740,"active":1,"login":1,"nologin":1,"imagetime":1529914079,"target_blank":0},{"id":8,"title1":"Bonus powitalny","title2":"500 PLN na start","link":"https:\/\/www.sts.pl\/\/pl\/bonusy\/#bonus-na-start","datetime_start":false,"datetime_end":false,"active":1,"login":0,"nologin":1,"imagetime":1510932568,"target_blank":0},{"id":42,"title1":"","title2":"","link":"http:\/\/redirect.sts.pl\/?r=pewny-start","datetime_start":1530172800,"datetime_end":1530223140,"active":1,"login":1,"nologin":1,"imagetime":1529825508,"target_blank":0},{"id":16,"title1":"FUNDACJA","title2":"Przeka\u017c 1%","link":"https:\/\/sporttwojaszansa.pl\/fundacja-opp","datetime_start":1521111600,"datetime_end":1524736800,"active":1,"login":1,"nologin":1,"imagetime":1521032856,"target_blank":0},{"id":15,"title1":"MOBILE BONUS","title2":"20 PLN czeka","link":"http:\/\/redirect.sts.pl\/?r=bonus-mobile","datetime_start":1526716800,"datetime_end":1526853300,"active":0,"login":0 ...
#             }
#
#             projectlib.init({"base":{"url-root":"https:\/\/www.sts.pl\/","url-gfx":"https:\/\/www.sts.pl\/pages\/frontend\/gfx\/","url-prematch-home":"https:\/\/www.sts.pl\/pl\/oferta\/zaklady-bukmacherskie\/","url-registration":"https:\/\/www.sts.pl\/pl\/registration\/","url-check-rankings":"https:\/\/www.sts.pl\/pl\/klub-sts\/sprawdz-rankingi","url-ga-aftelogin":"pl\/user\/logowanie\/?caller","actual-lang":"pl","is-guest":true,"expiration-limit":false,"fb-app-id":"243992215772277"},"messages":{"":"","KLIKNIJ I ODBIERZ 50 PLN NA GR\u0118":"KLIKNIJ I ODBIERZ 50 PLN NA GR\u0118","Dzi\u0119ki Twojemu kumplowi mo\u017cesz otrzyma\u0107 50 z\u0142otych na gr\u0119 w STS. Sprawd\u017a, co wystarczy zrobi\u0107.":"Dzi\u0119ki Twojemu kumplowi mo\u017cesz otrzyma\u0107 50 z\u0142otych na gr\u0119 w STS. Sprawd\u017a, co wystarczy zrobi\u0107.","Hej, chcesz wygra\u0107":"Hej, chcesz wygra\u0107","z STS.pl":"z STS.pl","Stawka":"Stawka","Zdarzenia":"Zdarzenia","Grupy":"Grupy","Ewentualna&nbsp;wygrana":"Ewentualna&nbsp;wygrana","Prosimy czeka\u0107, autoryzacja potrwa maksymalnie":"Prosimy czeka\u0107, autoryzacja potrwa maksymalnie","Coupon is being authorized":"Trwa autoryzacja kuponu","Mniej":"Mniej","Wi\u0119cej":"Wi\u0119cej"}});
#         </script>
# </div>
# <script src="https://www.sts.pl/userdata/files/clientjs-body.js?1565243312" type="text/javascript"></script>
# <script src="https://content.sts.pl/clientstyles/sts_pl/prod/clientbody.js" type="text/javascript"></script>
# </body>
# </html>

# %%
rows = soup.find_all('tr')

# %%
print(rows[2:6])
# Out:
# [<tr>
# <td class="bet tip1952" data-odds-id="825669387" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"2742","id_odds":"825669387","odds_value":"8.50","id_opportunity":"296924898","match_name":"Nysa - K\u0119dzierzyn","tip_name_formated":"Nysa","oppty_type_name":"mecz"});return false;'>
# <a href="#" rel="nofollow">
# Nysa
# <span>8.50</span>
# </a>
# </td>
# <td class="bet tip1951" data-odds-id="825669388" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"2742","id_odds":"825669388","odds_value":"1.07","id_opportunity":"296924898","match_name":"Nysa - K\u0119dzierzyn","tip_name_formated":"K\u0119dzierzyn","oppty_type_name":"mecz"});return false;'>
# <a href="#" rel="nofollow">
# Kędzierzyn
# <span>1.07</span>
# </a>
# </td>
# </tr>, <tr>
# <td class="date_time"><a href="/pl/zaklady-bukmacherskie/siatkowka/polska/plusliga/radom/183/6502/4142/296924906/">12.09 / 14:45</a></td>
# <td>
# <table class="subTable">
# <tr>
# <td class="bet tip1952" data-odds-id="825669403" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"43255","id_odds":"825669403","odds_value":"3.75","id_opportunity":"296924906","match_name":"Radom - Olsztyn","tip_name_formated":"Radom","oppty_type_name":"mecz"});return false;'>
# <a href="#" rel="nofollow">
# Radom
# <span>3.75</span>
# </a>
# </td>
# <td class="bet tip1951" data-odds-id="825669404" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"43255","id_odds":"825669404","odds_value":"1.27","id_opportunity":"296924906","match_name":"Radom - Olsztyn","tip_name_formated":"Olsztyn","oppty_type_name":"mecz"});return false;'>
# <a href="#" rel="nofollow">
# Olsztyn
# <span>1.27</span>
# </a>
# </td>
# </tr>
# </table>
# </td>
# <td class="support_bets"><a href="/pl/zaklady-bukmacherskie/siatkowka/polska/plusliga/radom/183/6502/4142/296924906/">30</a></td>
# <td class="stats">
# <a href="https://stats.sts.pl/pl/match/23403857" onclick="newPopup($(this).attr('href'),1250);return false;"></a>
# </td>
# <td class="bet_id">
# <a href="/pl/zaklady-bukmacherskie/siatkowka/polska/plusliga/radom/183/6502/4142/296924906/">
# 43255
# </a>
# </td>
# </tr>, <tr>
# <td class="bet tip1952" data-odds-id="825669403" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"43255","id_odds":"825669403","odds_value":"3.75","id_opportunity":"296924906","match_name":"Radom - Olsztyn","tip_name_formated":"Radom","oppty_type_name":"mecz"});return false;'>
# <a href="#" rel="nofollow">
# Radom
# <span>3.75</span>
# </a>
# </td>
# <td class="bet tip1951" data-odds-id="825669404" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"43255","id_odds":"825669404","odds_value":"1.27","id_opportunity":"296924906","match_name":"Radom - Olsztyn","tip_name_formated":"Olsztyn","oppty_type_name":"mecz"});return false;'>
# <a href="#" rel="nofollow">
# Olsztyn
# <span>1.27</span>
# </a>
# </td>
# </tr>, <tr>
# <td class="date_time"><a href="/pl/zaklady-bukmacherskie/siatkowka/polska/plusliga/lubin/183/6502/4142/296924893/">12.09 / 17:30</a></td>
# <td>
# <table class="subTable">
# <tr>
# <td class="bet tip1952" data-odds-id="825669377" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"2688","id_odds":"825669377","odds_value":"8.50","id_opportunity":"296924893","match_name":"Lubin - Be\u0142chat\u00f3w","tip_name_formated":"Lubin","oppty_type_name":"mecz"});return false;'>
# <a href="#" rel="nofollow">
# Lubin
# <span>8.50</span>
# </a>
# </td>
# <td class="bet tip1951" data-odds-id="825669378" onclick='handlerPrematchTicket(this, "TICKET_HANDLE", {"oppty_info_number":"2688","id_odds":"825669378","odds_value":"1.07","id_opportunity":"296924893","match_name":"Lubin - Be\u0142chat\u00f3w","tip_name_formated":"Be\u0142chat\u00f3w","oppty_type_name":"mecz"});return false;'>
# <a href="#" rel="nofollow">
# Bełchatów
# <span>1.07</span>
# </a>
# </td>
# </tr>
# </table>
# </td>
# <td class="support_bets"><a href="/pl/zaklady-bukmacherskie/siatkowka/polska/plusliga/lubin/183/6502/4142/296924893/">30</a></td>
# <td class="stats">
# <a href="https://stats.sts.pl/pl/match/23403859" onclick="newPopup($(this).attr('href'),1250);return false;"></a>
# </td>
# <td class="bet_id">
# <a href="/pl/zaklady-bukmacherskie/siatkowka/polska/plusliga/lubin/183/6502/4142/296924893/">
# 2688
# </a>
# </td>
# </tr>]
